# %% [markdown]
# # Fine-tuning Demo (CPU, <5min)
# Demonstrates incremental learning on catalyst data

# %%
from backend.app.ml.catalyst_predictor import CatalystGNNPredictor
from backend.app.ml.base import ModelInput

# Dummy experimental data
data = [
    (ModelInput(smiles="TiO2"), {"activity": 2.5, "selectivity": 0.9}),
    (ModelInput(smiles="ZrO2"), {"activity": 1.8, "selectivity": 0.85})
]

predictor = CatalystGNNPredictor()
predictor.fine_tune(data)
print("Fine-tuning complete!")
